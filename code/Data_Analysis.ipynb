# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
plt.style.use('classic')
random.seed(42)

# %%
R_train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/STATS 201/Regression_Train.csv", index_col="Unnamed: 0")
R_test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/STATS 201/Regression_Test.csv")

# %%
R_train.isna().sum()
# Out:
# energy_per_capita    0
# gdp_per_capita       0
# dtype: int64

# %%
R_train.head()
# Out:
#      energy_per_capita  gdp_per_capita
# 89          953.201548     1015.950361
# 59         7502.305405     7693.203562
# 36       106799.608845    24808.737198
# 92          892.842905     1536.575944
# 123       98663.451897    39032.010531

# %%
R_test.head()
# Out:
#    Unnamed: 0  energy_per_capita  gdp_per_capita
# 0         213       11806.431966    10714.285462
# 1          79       13708.618833     8501.753598
# 2         170       25148.893786    25220.620671
# 3          88        3712.472500     5971.396550
# 4         138       21640.178500    12635.043578

# %%
from sklearn.metrics import r2_score

# %%
R_train.head()
# Out:
#      energy_per_capita  gdp_per_capita
# 89          953.201548     1015.950361
# 59         7502.305405     7693.203562
# 36       106799.608845    24808.737198
# 92          892.842905     1536.575944
# 123       98663.451897    39032.010531

# %%
X_train = pd.DataFrame(R_train['gdp_per_capita'])
y_train = pd.DataFrame(R_train['energy_per_capita'])

# %%
R_test.head()
# Out:
#    Unnamed: 0  energy_per_capita  gdp_per_capita
# 0         213       11806.431966    10714.285462
# 1          79       13708.618833     8501.753598
# 2         170       25148.893786    25220.620671
# 3          88        3712.472500     5971.396550
# 4         138       21640.178500    12635.043578

# %%
X_test = pd.DataFrame(R_test['gdp_per_capita'])
y_test = pd.DataFrame(R_test['energy_per_capita'])

# %% [markdown]
# #Linear Regression

# %%
from sklearn import linear_model

# %%
mdl = linear_model.LinearRegression().fit(X_train,y_train)

# %%
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# R2 Score: 0.6411474215142317

# %%
y_pred = pd.DataFrame(np.array(mdl.predict(X_test)).astype(float),columns=['y_pred'])
y_pred
# Out:
#           y_pred
# 0   22399.058965
# 1   18777.221648
# 2   46145.422598
# 3   14635.115615
# 4   25543.272857
# 5    6491.405201
# 6   33090.812068
# 7   16632.971480
# 8    6875.074715
# 9   63462.120139
# 10  26280.481344
# 11  35257.531099
# 12  35196.013944
# 13  15379.057082
# 14  58096.667864
# 15  14687.845588
# 16  31727.429463
# 17  20285.872581
# 18  28566.714922
# 19  27122.834272
# 20  37136.820048
# 21  41150.542720
# 22  18547.290636
# 23   9501.830149
# 24   7069.710742
# 25  20690.064948
# 26   6362.729994
# 27  48938.603047
# 28  21333.431622
# 29  20691.344207
# 30  19922.732484
# 31   9935.160380
# 32  22682.591822
# 33  29927.708677

# %%
fig, ax = plt.subplots()

y_test.hist(ax=ax, label='true', alpha=.75)
y_pred.hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()

# %% [markdown]
# #Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
mdl = RandomForestRegressor().fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
# calculate R2
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test, mdl.predict(X_test))
print(f'R2 Score: {r2}')
# Out:
# R2 Score: 0.26857352163470016

# %%
y_pred = pd.DataFrame(np.array(mdl.predict(X_test)).astype(float),columns=['y_pred'])
y_pred
# Out:
#           y_pred
# 0   25915.655601
# 1   40883.958518
# 2   70097.701457
# 3    7402.691841
# 4   24522.568380
# 5     800.133373
# 6   38700.853302
# 7    8197.873524
# 8     560.089457
# 9   85469.714637
# 10  18803.221801
# 11  56855.766534
# 12  56855.766534
# 13  17693.804389
# 14  79063.572617
# 15   7721.183385
# 16  49395.623916
# 17  13745.848308
# 18  18108.568251
# 19  22110.515876
# 20  58693.709318
# 21  51162.137663
# 22  40632.415358
# 23   7367.405796
# 24    736.685104
# 25  11987.278637
# 26    621.651637
# 27  64027.643817
# 28  12302.194103
# 29  11987.278637
# 30  17214.586549
# 31   3611.831926
# 32  39159.966474
# 33  28726.663706

# %%
fig, ax = plt.subplots()

y_test.hist(ax=ax, label='true', alpha=.75)
y_pred.hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()

# %% [markdown]
# #Auto ML

# %%
train_df = pd.DataFrame(X_train)
train_df['target'] = y_train.values

test_df = pd.DataFrame(X_test)
test_df['target'] = y_test.values

# %%
# !pip install autogluon

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_data = TabularDataset(train_df)
test_data = TabularDataset(test_df)

# %%
predictor = TabularPredictor(
    path='AutogluonModels/regression/',
    label='target'
).fit(train_data)

# %%
predictor = TabularPredictor.load("AutogluonModels/regression/")

# %%
# reference: https://auto.gluon.ai/stable/cheatsheet.html
# https://auto.gluon.ai/0.3.1/api/autogluon.tabular.models.html
predictor.leaderboard(silent=True, data=test_data, extra_metrics=["root_mean_squared_error", "mean_squared_error", "mean_absolute_error", "median_absolute_error", "r2"])
# Out:
#                   model    score_test  root_mean_squared_error  \
# 0       NeuralNetFastAI -12511.513082            -12511.513082
# 1              CatBoost -15114.959943            -15114.959943
# 2        KNeighborsDist -15645.625823            -15645.625823
# 3        KNeighborsUnif -16355.365635            -16355.365635
# 4        NeuralNetTorch -16598.820018            -16598.820018
# 5   WeightedEnsemble_L2 -16598.820018            -16598.820018
# 6         ExtraTreesMSE -16719.894946            -16719.894946
# 7       RandomForestMSE -18184.206312            -18184.206312
# 8               XGBoost -18556.167460            -18556.167460
# 9         LightGBMLarge -18933.008148            -18933.008148
# 10           LightGBMXT -18982.145206            -18982.145206
# 11             LightGBM -18999.212338            -18999.212338
#
#     mean_squared_error  mean_absolute_error  median_absolute_error        r2  \
# 0        -1.565380e+08         -9463.256442           -6360.618476  0.628196
# 1        -2.284620e+08         -9650.728149           -5378.433927  0.457365
# 2        -2.447856e+08        -10730.470457           -7596.535228  0.418593
# 3        -2.674980e+08        -10233.309357           -5047.512776  0.364648
# 4        -2.755208e+08         -9353.115854           -5148.955510  0.345592
# 5        -2.755208e+08         -9353.115854           -5148.955510  0.345592
# 6        -2.795549e+08        -11569.339550           -7664.456338  0.336011
# 7        -3.306654e+08        -12843.421717           -9688.308970  0.214615
# 8        -3.443314e+08        -13133.673768           -9710.147225  0.182156
# 9        -3.584588e+08        -11953.755990           -7979.680332  0.148601
# 10       -3.603218e+08        -14246.154360          -11538.897982  0.144176
# 11       -3.609701e+08        -14046.316749          -11471.050326  0.142636
#
#        score_val              eval_metric  pred_time_test  pred_time_val  \
# 0  -11519.001209  root_mean_squared_error        0.091902       0.008107
# 1   -9714.925676  root_mean_squared_error        0.004260       0.001702
# 2  -12763.088347  root_mean_squared_error        0.053198       0.017792
# 3   -9603.679617  root_mean_squared_error        0.044584       0.020716
# 4   -6986.055544  root_mean_squared_error        0.016125       0.005988
# 5   -6986.055544  root_mean_squared_error        0.021651       0.006747
# 6  -10466.408198  root_mean_squared_error        0.261355       0.079701
# 7  -12620.041701  root_mean_squared_error        0.191898       0.067742
# 8  -13611.447934  root_mean_squared_error        0.046515       0.005294
# 9   -8220.743393  root_mean_squared_error        0.008303       0.002890
# 10 -14274.635255  root_mean_squared_error        0.136117       0.025383
# 11 -14365.570190  root_mean_squared_error        0.023402       0.002562
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   0.995483                 0.091902                0.008107
# 1   0.204960                 0.004260                0.001702
# 2   0.006563                 0.053198                0.017792
# 3   0.016268                 0.044584                0.020716
# 4   0.765128                 0.016125                0.005988
# 5   1.327082                 0.005525                0.000758
# 6   0.614739                 0.261355                0.079701
# 7   0.647851                 0.191898                0.067742
# 8   0.143688                 0.046515                0.005294
# 9   0.544652                 0.008303                0.002890
# 10  0.950678                 0.136117                0.025383
# 11  0.573783                 0.023402                0.002562
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.995483            1       True          8
# 1            0.204960            1       True          6
# 2            0.006563            1       True          2
# 3            0.016268            1       True          1
# 4            0.765128            1       True         10
# 5            0.561954            2       True         12
# 6            0.614739            1       True          7
# 7            0.647851            1       True          5
# 8            0.143688            1       True          9
# 9            0.544652            1       True         11
# 10           0.950678            1       True          3
# 11           0.573783            1       True          4

# %%
r2 = r2_score(y_test,
              predictor.predict(
                  X_test)
              )
print(f'R2 Score: {r2}')
# Out:
# R2 Score: 0.34559212299301634

# %%
y_pred = predictor.predict(X_test)
y_pred
# Out:
# 0     19298.410156
# 1     14895.196289
# 2     70167.664062
# 3      8949.483398
# 4     25255.435547
# 5         9.608423
# 6     39902.156250
# 7     11846.606445
# 8       352.817200
# 9     98110.476562
# 10    25825.150391
# 11    49907.382812
# 12    49796.882812
# 13    10459.637695
# 14    95417.898438
# 15     9174.745117
# 16    38921.246094
# 17    15539.093750
# 18    29496.687500
# 19    26516.875000
# 20    53878.367188
# 21    59820.730469
# 22    14795.715820
# 23     2456.160889
# 24      562.451477
# 25    16101.630859
# 26        0.002072
# 27    72961.789062
# 28    17388.783203
# 29    16107.432617
# 30    15386.241211
# 31     2969.968506
# 32    20115.339844
# 33    36377.296875
# Name: target, dtype: float32

# %%
fig, ax = plt.subplots()

y_test.hist(ax=ax, label='true', alpha=.75)
y_pred.hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()
